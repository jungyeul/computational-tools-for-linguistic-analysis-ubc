# %% [markdown]
# ### PTB examples

# %%
from nltk.tree.tree import Tree

ptb = [
'(TOP (S (NP (NP (JJ Influential) (NNS members)) (PP (IN of) (NP (DT the) (NNP House) (NML (NNP Ways) (CC and) (NNP Means)) (NNP Committee)))) (VP (VBD introduced) (NP (NP (NN legislation)) (SBAR (WHNP (WDT that)) (S (VP (MD would) (VP (VB restrict) (SBAR (WHADVP (WRB how)) (S (NP (DT the) (JJ new) (NML (NML (NNS savings) (HYPH -) (CC and) (HYPH -) (NN loan)) (NN bailout)) (NN agency)) (VP (MD can) (VP (VB raise) (NP (NN capital)))))) (, ,) (S (VP (VBG creating) (NP (NP (DT another) (JJ potential) (NN obstacle)) (PP (IN to) (NP (NP (NP (DT the) (NN government) (POS \'s)) (NN sale)) (PP (IN of) (NP (JJ sick) (NNS thrifts)))))))))))))) (. .)))', 
'(TOP (S (NP (NP (DT The) (JJ complex) (NN financing) (NN plan)) (PP (IN in) (NP (DT the) (NML (NN S&L) (NN bailout)) (NN law)))) (VP (VBZ includes) (S (VP (VBG raising) (NP (QP ($ $) (CD 30) (CD billion))) (PP (IN from) (NP (NP (NN debt)) (VP (VBN issued) (PP (IN by) (NP (DT the) (ADJP (RB newly) (VBN created)) (NNP RTC))))))))) (. .)))', 
'(TOP (S (NP (DT This) (NN financing) (NN system)) (VP (VBD was) (VP (VBN created) (PP (IN in) (NP (DT the) (JJ new) (NN law))) (SBAR (IN in) (NN order) (S (VP (TO to) (VP (VB keep) (NP (DT the) (NN bailout) (NN spending)) (PP (IN from) (S (VP (VBG swelling) (NP (DT the) (NN budget) (NN deficit))))))))))) (. .)))', 
'(TOP (S (NP (QP (DT Another) ($ $) (CD 20) (CD billion))) (VP (MD would) (VP (VB be) (VP (VBN raised) (PP (IN through) (NP (NP (NNP Treasury) (NNS bonds)) (, ,) (SBAR (WHNP (WDT which)) (S (VP (VBP pay) (NP (JJR lower) (NN interest) (NNS rates)))))))))) (. .)))', 
'(TOP (S (NP (DT That) (NN debt)) (VP (MD would) (VP (VB be) (VP (VBN paid) (PRT (RP off)) (SBAR (IN as) (S (NP (DT the) (NNS assets)) (VP (VBP are) (VP (VBN sold))))) (, ,) (S (VP (VBG leaving) (NP (NP (DT the) (JJ total) (NN spending)) (PP (IN for) (NP (DT the) (NN bailout)))) (PP (IN at) (NP (NP (QP ($ $) (CD 50) (CD billion))) (, ,) (CC or) (NP (NP (QP ($ $) (CD 166) (CD billion))) (PP (VBG including) (NP (NP (NN interest)) (PP (IN over) (NP (CD 10) (NNS years))))))))))))) (. .)))', 
'(TOP (S (S (NP (DT The) (NN agency)) (VP (VBZ has) (ADVP (RB already)) (VP (VBN spent) (NP (QP (RB roughly) ($ $) (CD 19) (CD billion))) (S (VP (VBG selling) (NP (CD 34) (JJ insolvent) (NNS S&Ls))))))) (, ,) (CC and) (S (NP (PRP it)) (VP (VBZ is) (ADJP (JJ likely) (S (VP (TO to) (VP (VB sell) (CC or) (VB merge) (NP (CD 600)) (PP (IN by) (NP (NP (DT the) (NN time)) (SBAR (S (NP (DT the) (NN bailout)) (VP (VBZ concludes)))))))))))) (. .)))', 
'(TOP (S (S (ADJP (JJ Absent)) (NP (JJ other) (NN working) (NN capital))) (PRN (, ,) (S (NP (PRP he)) (VP (VBD said))) (, ,)) (NP (DT the) (NNP RTC)) (VP (MD would) (VP (VB be) (VP (VBN forced) (S (VP (TO to) (VP (VB delay) (NP (JJ other) (NN thrift) (NNS resolutions)) (SBAR (IN until) (S (NP (NN cash)) (VP (MD could) (VP (VB be) (VP (VBN raised) (PP (IN by) (S (VP (VBG selling) (NP (DT the) (JJ bad) (NNS assets)))))))))))))))) (. .)))', 
'(TOP (S (NP (NP (DT The) (VBN complicated) (NN language)) (PP (IN in) (NP (DT the) (JJ huge) (JJ new) (NN law)))) (VP (VBZ has) (VP (VBN muddied) (NP (DT the) (NN fight)))) (. .)))', 
'(TOP (S (NP (DT The) (NN law)) (VP (VBZ does) (VP (VB allow) (S (NP (DT the) (NNP RTC)) (VP (TO to) (VP (VB borrow) (PP (IN from) (NP (DT the) (NNP Treasury))) (NP (QP (IN up) (IN to) ($ $) (CD 5) (CD billion))) (PP (IN at) (NP (DT any) (NN time)))))))) (. .)))', 
'(TOP (S (NP (DT The) (NML (NNP Ways) (CC and) (NNP Means)) (NNP Committee)) (VP (MD will) (VP (VB hold) (NP (NP (DT a) (NN hearing)) (PP (IN on) (NP (DT the) (NN bill)))) (NP (IN next) (NNP Tuesday)))) (. .)))', 
'(TOP (S (NP (PRP We)) (VP (VBP are) (ADJP (JJ about) (S (VP (TO to) (VP (VB see) (SBAR (IN if) (S (NP (NN advertising)) (VP (VBZ works))))))))) (. .)))', 
]

# %%
for line in ptb:
    # print(line)
    if len(line) > 0:
        tree = Tree.fromstring(line)
        tree.pretty_print()
    # break
# Out:
#                                                                                                                                           TOP
#                                                                                                                                            |
#                                                                                                                                            S
#                     _______________________________________________________________________________________________________________________|___________________________________________________________________________________________________________________________________________
#                    |                                                                   VP                                                                                                                                                                                              |
# ...
