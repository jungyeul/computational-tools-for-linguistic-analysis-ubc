# %% [markdown]
# Complete your lab 1 (5 pts), and do some exercises in shell programming (add your comments, extra pts) (Due Sep 13, 2022)

# %%
# !ls
# Out:
# eng.txt    lab1.ipynb

# %%
# !ls -l
# Out:
# total 35216
# -rw-rw-r--@ 1 jungyeul  staff  18023095 May  8 08:31 eng.txt
# -rw-r--r--@ 1 jungyeul  staff      1143 Sep  7 07:01 lab1.ipynb

# %%
# !mkdir tempo

# %%
# !ls -l
# Out:
# total 35216
# -rw-rw-r--@ 1 jungyeul  staff  18023095 May  8 08:31 eng.txt
# -rw-r--r--@ 1 jungyeul  staff      1143 Sep  7 07:01 lab1.ipynb
# drwxr-xr-x  2 jungyeul  staff        64 Sep  7 07:05 tempo

# %% [markdown]
# Run following commands:
# ```
# $  wget https://raw.githubusercontent.com/unimorph/eng/master/eng
# $  file eng
# $  cut -f1 eng | sort | uniq -c
# ```
