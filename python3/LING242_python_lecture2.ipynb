# %% [markdown]
# # LING 242 Python Lecture 2: Corpora
#
# * Some (circularly defined) terminology
# * Corpora in NLTK
# * NLTK corpus readers
# * Annotations
# * Other corpora and annotations
# * Which corpus?

# %% [markdown]
# ## Some (circularly defined) terminology

# %% [markdown]
# * Corpus: a collection of documents
# * Document (D): a sequence of word tokens
# * Token: a particular instance of a type in a document
# * Type: a distinct word form, often appearing in multiple tokens across documents, corpora
# * Lexicon: a collection of word types, possibly with associated information
# * Vocabulary (V): a list of all word types in a corpus
# * *n*-grams: a fixed length sequence of words (unigram, bigram, trigram, 4-gram,...). $n$-grams also have type/token distinction

# %% [markdown]
# Let's look at tokens, types, and vocabulary in the first corpus ever: the Brown corpus

# %%
# !python3 -m pip install --user nltk
# Out:
# Requirement already satisfied: nltk in /Users/jungyeul/Library/Python/3.8/lib/python/site-packages (3.6.5)
# Requirement already satisfied: joblib in /Users/jungyeul/Library/Python/3.8/lib/python/site-packages (from nltk) (1.1.0)
# Requirement already satisfied: click in /Users/jungyeul/Library/Python/3.8/lib/python/site-packages (from nltk) (8.0.3)
# Requirement already satisfied: tqdm in /Users/jungyeul/Library/Python/3.8/lib/python/site-packages (from nltk) (4.62.3)
# Requirement already satisfied: regex>=2021.8.3 in /Users/jungyeul/Library/Python/3.8/lib/python/site-packages (from nltk) (2021.10.23)

# %%
import nltk
nltk.download("brown")
from nltk.corpus import brown
# Out:
# [nltk_data] Downloading package brown to /Users/jungyeul/nltk_data...
# [nltk_data]   Package brown is already up-to-date!

# %%
print(brown.words()[:10])
# Out:
# ['The', 'Fulton', 'County', 'Grand', 'Jury', 'said', 'Friday', 'an', 'investigation', 'of']

# %%
print(len(brown.words()))
# Out:
# 1161192

# %%
len(brown.words())
# Out:
# 1161192

# %%
Out[5]+1
# Out:
# 1161193

# %%
types = set(brown.words())
print(len(list(types)))
# Out:
# 56057

# %%
list(types)[:10]
# Out:
# ['Scala',
#  'Use',
#  'resplendent',
#  'Mts.',
#  'Schiele',
#  'affronting',
#  'Stands',
#  'Holes',
#  'concurrence',
#  'sapping']

# %%
len(types)
# Out:
# 56057

# %% [markdown]
# An important statistical property shared by all natural language corpora: Most of the tokens come from a small set of common types, and most of the vocabulary consists of rare types.

# %%
import pylab
import collections

counts = collections.Counter(word.lower() for word in brown.words())

# %%
import pylab
from collections import Counter

counts = Counter(word.lower() for word in brown.words())

def print_zipf(loglog=False,top_n=100000):
    ranks = range(1, min(len(counts) +1, top_n + 1))
    frequencies = sorted(counts.values(),reverse=True)[:top_n]
    if loglog:
        pylab.loglog(ranks, frequencies, marker="+")
        pylab.title("Zipf plot for Brown corpus word types (log-log)")
    else:
        pylab.plot(ranks, frequencies, marker="+")
        pylab.title("Zipf plot for Brown corpus word types")

    pylab.xlabel("Frequency rank of word type")
    pylab.ylabel("Absolute frequency of word type")
    pylab.show()

# %%
print_zipf()

# %%
print_zipf(top_n=100)

# %%
print_zipf(loglog=True)

# %% [markdown]
# If a log-log plot of word rank against frequency is roughly linear, this means it is obeying [Zipf's law](https://en.wikipedia.org/wiki/Zipf%27s_law). The simple formulation of this law is that the frequency of a word (type) in a corpus will be inversely proportional to its frequency rank. The law was first noticed with respect to the Brown corpus, but it holds for much larger corpora in many different languages, for example Wikipedias:
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/a/ac/Zipf_30wiki_en_labels.png/1024px-Zipf_30wiki_en_labels.png" alt="drawing" width="400"/>
#
# (from the Wikipedia entry, by SergioJimenez, numbers are millions)

# %% [markdown]
# One upshot of *Zipf's law* is that most words have very low frequency. Let's count the number of word types that only appear once in the Brown (These types are known as *hapax legomena*).

# %%
hapax_count = 0
#my code here
for count in counts.values():
    if count == 1:
        hapax_count += 1
#my code here
hapax_count
# Out:
# 22010

# %% [markdown]
# This basic fact about words and corpora has wide-ranging implications that will motivate many of the approaches to computational linguistics we talk about throughout this program!

# %% [markdown]
# ## Corpora in NLTK

# %% [markdown]
# The Natural Language Toolkit or NLTK is a venerable Python package for doing computational linguistics. Though no longer a source for cutting-edge NLP tools, it is designed for learning CL concepts and we will use it in various ways during this program. One way it will be most useful to us as is an easy source of a (relatively) diverse set of publicly-available corpora.

# %%
import nltk

# %% [markdown]
# The cell below will download all the corpus mentioned in this lecture. You can also just download everything with `nltk.download("all")` though this will take a while and use a fair bit of hard disk space!

# %%
for corpus in ["movie_reviews", "treebank", "brown", "gutenberg", "switchboard", "sinica_treebank", "udhr2", "knbc", "reuters", "indian", "europarl_raw", "cess_esp", "alpino", "twitter_samples", "floresta", "webtext", "nps_chat", "stopwords", "punkt","universal_tagset"]:
    nltk.download(corpus)
# Out:
# [nltk_data] Downloading package movie_reviews to
# [nltk_data]     /Users/jungyeul/nltk_data...
# [nltk_data]   Package movie_reviews is already up-to-date!
# [nltk_data] Downloading package treebank to
# [nltk_data]     /Users/jungyeul/nltk_data...
# [nltk_data]   Package treebank is already up-to-date!
# [nltk_data] Downloading package brown to /Users/jungyeul/nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# [nltk_data] Downloading package gutenberg to
# [nltk_data]     /Users/jungyeul/nltk_data...
# [nltk_data]   Package gutenberg is already up-to-date!
# [nltk_data] Downloading package switchboard to
# [nltk_data]     /Users/jungyeul/nltk_data...
# [nltk_data]   Package switchboard is already up-to-date!
# [nltk_data] Downloading package sinica_treebank to
# [nltk_data]     /Users/jungyeul/nltk_data...
# [nltk_data]   Package sinica_treebank is already up-to-date!
# [nltk_data] Downloading package udhr2 to /Users/jungyeul/nltk_data...
# [nltk_data]   Package udhr2 is already up-to-date!
# [nltk_data] Downloading package knbc to /Users/jungyeul/nltk_data...
# [nltk_data]   Package knbc is already up-to-date!
# [nltk_data] Downloading package reuters to
# [nltk_data]     /Users/jungyeul/nltk_data...
# [nltk_data]   Package reuters is already up-to-date!
# [nltk_data] Downloading package indian to /Users/jungyeul/nltk_data...
# [nltk_data]   Package indian is already up-to-date!
# [nltk_data] Downloading package europarl_raw to
# [nltk_data]     /Users/jungyeul/nltk_data...
# [nltk_data]   Package europarl_raw is already up-to-date!
# [nltk_data] Downloading package cess_esp to
# [nltk_data]     /Users/jungyeul/nltk_data...
# [nltk_data]   Package cess_esp is already up-to-date!
# [nltk_data] Downloading package alpino to /Users/jungyeul/nltk_data...
# [nltk_data]   Package alpino is already up-to-date!
# [nltk_data] Downloading package twitter_samples to
# [nltk_data]     /Users/jungyeul/nltk_data...
# [nltk_data]   Package twitter_samples is already up-to-date!
# [nltk_data] Downloading package floresta to
# [nltk_data]     /Users/jungyeul/nltk_data...
# [nltk_data]   Package floresta is already up-to-date!
# [nltk_data] Downloading package webtext to
# [nltk_data]     /Users/jungyeul/nltk_data...
# [nltk_data]   Package webtext is already up-to-date!
# [nltk_data] Downloading package nps_chat to
# [nltk_data]     /Users/jungyeul/nltk_data...
# [nltk_data]   Package nps_chat is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/jungyeul/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/jungyeul/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package universal_tagset to
# [nltk_data]     /Users/jungyeul/nltk_data...
# [nltk_data]   Package universal_tagset is already up-to-date!

# %% [markdown]
# Let's take a quick tour of some of the corpora available via NLTK. Other than the Brown and the Treebank, you don't need to remember the names of individual corpora, but you should have at least develop a sense of the major ways corpora can vary, in terms of
#
# * source
# * size
# * genre
# * time period
# * annotations
#
# One of the most popular ways to look at the contents of a corpus is a word cloud, so in addition to some basic information we are going to show you one for each corpus. In a word cloud, the size of a word reflects its frequency.

# %%
# !pip install wordcloud
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: wordcloud in /Users/jungyeul/Library/Python/3.8/lib/python/site-packages (1.8.1)
# Requirement already satisfied: pillow in /Users/jungyeul/Library/Python/3.8/lib/python/site-packages (from wordcloud) (8.4.0)
# Requirement already satisfied: matplotlib in /Users/jungyeul/Library/Python/3.8/lib/python/site-packages (from wordcloud) (3.4.3)
# Requirement already satisfied: numpy>=1.6.1 in /Users/jungyeul/Library/Python/3.8/lib/python/site-packages (from wordcloud) (1.21.3)
# Requirement already satisfied: cycler>=0.10 in /Users/jungyeul/Library/Python/3.8/lib/python/site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/jungyeul/Library/Python/3.8/lib/python/site-packages (from matplotlib->wordcloud) (1.3.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/jungyeul/Library/Python/3.8/lib/python/site-packages (from matplotlib->wordcloud) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/jungyeul/Library/Python/3.8/lib/python/site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.15.0)

# %% [markdown]
# Here's a function that's going to give us basic info about each corpus. Note that there's a special "corpus" of common English words like ("the", "of", etc.) called _stopwords_, and we will filter these out to get a better sense of what each corpus is about.

# %%
from nltk.corpus import movie_reviews, treebank, brown, gutenberg, switchboard, sinica_treebank, udhr2, genesis, knbc, reuters, indian, europarl_raw, cess_esp, alpino, twitter_samples, floresta, webtext, nps_chat, stopwords
from collections import Counter
import matplotlib.pyplot as plt
from wordcloud import WordCloud

stopwords_set = stopwords.words("English")
stopwords_set.extend(["would", "could", "one", "may"])

def corpus_info(corpus):
    counter = Counter(word.lower() for word in corpus.words())
    print("Total tokens:", sum(list(counter.values())))
    print("Vocabulary size:", len(counter))
    print("Number of documents:", len(corpus.fileids()))
    print("Most common words:", " ".join([pair[0] for pair in counter.most_common(10)]))
    print("Most common words excluding stopwords:", " ".join([pair[0] for pair in counter.most_common(500) if pair[0].isalpha() and pair[0].lower() not in stopwords_set][:10]))
    print("Wordcloud:")
    wordcloud = WordCloud(stopwords = stopwords_set).generate(" ".join(corpus.words()))
    plt.imshow(wordcloud)
    plt.axis("off")
    plt.show()

# %% [markdown]
# ### [The Brown Corpus](https://en.wikipedia.org/wiki/Brown_Corpus)
#
# * The original corpus linguistics corpus (Kučera and Francis 1967)
# * First major machine-readable corpus
# * 500 documents
# * "Balanced" corpus of 15 text genres, used in studies of genre
# * Huge at the time, now a bit small!

# %%
corpus_info(brown)
# Out:
# Total tokens: 1161192
# Vocabulary size: 49815
# Number of documents: 500
# Most common words: the , . of and to a in that is
# Most common words excluding stopwords: said new time two first like man even made also
# Wordcloud:

# %% [markdown]
# ### [The Penn Treebank](https://catalog.ldc.upenn.edu/LDC99T42)
#
# * Primarily Wall Street Journal articles from 1989
# * 2500 documents in total
# * Only a ~200 document sample in NLTK, full version requires LDC subscription
# * The first large corpus with parse trees, used extensively for parsing and syntactic analysis

# %%
corpus_info(treebank)
# Out:
# Total tokens: 100676
# Vocabulary size: 11387
# Number of documents: 199
# Most common words: , the . of to a in and *-1 0
# Most common words excluding stopwords: said million new company says year market stock trading also
# Wordcloud:

# %% [markdown]
# ### [Switchboard corpus](https://catalog.ldc.upenn.edu/LDC97S62)
#
# * 36 transcribed telephone conversations
# * Calls between strangers in 1990-1
# * Useful for study of dialogue acts

# %%
corpus_info(switchboard)
# Out:
# Total tokens: 82792
# Vocabulary size: 4376
# Number of documents: 1
# Most common words: , . i and the you that it a to
# Most common words excluding stopwords: uh know yeah like well think right um oh really
# Wordcloud:

# %% [markdown]
# ### Gutenberg
#
# * Out of copyright documents from [Project Gutenberg](https://www.gutenberg.org/)
# * Mostly classic literature from before 1900
# * NLTK just has a small sample, but tens of thousands available

# %%
corpus_info(gutenberg)
# Out:
# Total tokens: 2621613
# Vocabulary size: 42339
# Number of documents: 18
# Most common words: , the and . of to : a in i
# Most common words excluding stopwords: shall said unto lord thou man thy god thee ye
# Wordcloud:

# %% [markdown]
# ### Internet-derived copora
#
# * 2000 movie reviews from a IMDB newsgroup (movie_reviews)
# * 10K IM chat posts (nps_chat)
# * Collection of various text from the web (webtext)
# * Sample of tweets (twitter_samples)

# %%
corpus_info(movie_reviews)
# Out:
# Total tokens: 1583820
# Vocabulary size: 39768
# Number of documents: 2000
# Most common words: , the . a and of to ' is in
# Most common words excluding stopwords: film movie like even good time story much character also
# Wordcloud:

# %% [markdown]
# ### Non-English Corpora

# %% [markdown]
# * Balanced corpus of Chinese (sinica_treebank)
# * Japanese blogs (knbc)
# * Samples from various Indian languages (indian)
# * News articles from Spanish languages (cess_esp,cess_cat)
# * Portuguese (floresta)
# * Dutch (alpino)
# * Europearn parliment proceedings (europarl_raw)
# * Universal declaration of human rights in 300+ languages

# %%
corpus_info(sinica_treebank)
# Out:
# Total tokens: 91627
# Vocabulary size: 17273
# Number of documents: 1
# Most common words: 的 、 在 是 了 有 我 他 就 上
# Most common words excluding stopwords: 的 在 是 了 有 我 他 就 上 和
# Wordcloud:

# %% [markdown]
# ## NLTK corpus readers

# %% [markdown]
# Most of the corpora in NLTK have *corpus readers* (code which converts raw text files to Python data structures) which conform to a single unified standard.
#
# The simplest way to access a corpus is by iterating over the tokens using the `words()` method. Each word is a string.

# %%
for word in brown.words():
    print(word)
    if word == "that":
        break
# Out:
# The
# Fulton
# County
# Grand
# Jury
# said
# Friday
# an
# investigation
# of
# Atlanta's
# recent
# primary
# election
# produced
# ``
# no
# evidence
# ''
# that

# %% [markdown]
# Most corpora are divided into sentences, which for NLTK corpora can be accessed iteratively using `sents()` method. Sentences are a lists of words. Some corpora (like the Brown) also have paragraphs (`paras()`), which are lists of sentences.

# %%
for sent in brown.sents():
    print(len(sent))
    if len(sent) > 25:
        print(sent)
        break
# Out:
# 25
# 43
# ['The', 'jury', 'further', 'said', 'in', 'term-end', 'presentments', 'that', 'the', 'City', 'Executive', 'Committee', ',', 'which', 'had', 'over-all', 'charge', 'of', 'the', 'election', ',', '``', 'deserves', 'the', 'praise', 'and', 'thanks', 'of', 'the', 'City', 'of', 'Atlanta', "''", 'for', 'the', 'manner', 'in', 'which', 'the', 'election', 'was', 'conducted', '.']

# %% [markdown]
# Let's print out all the sentences in the Brown that contain some particular word, your choice (but nothing too common or too rare)!

# %%
for sent in brown.sents():
    if "ridiculous" in sent:
        print(sent)
# Out:
# ['But', 'when', 'tiny', ',', '145-pound', 'Albert', 'Gregory', 'Pearson', 'of', 'the', 'Los', 'Angeles', 'Angels', ',', 'who', 'once', 'caught', 'three', 'straight', 'fly', 'balls', 'in', 'center', 'field', 'because', ',', 'as', 'a', 'teammate', 'explained', ',', '``', 'the', 'other', 'team', 'thought', 'no', 'one', 'was', 'out', 'there', "''", ',', 'hits', 'seven', 'home', 'runs', 'in', 'four', 'months', '(', 'three', 'more', 'than', 'his', 'total', 'in', '1958', ',', '1959', ',', 'and', '1960', ')', ',', 'his', 'achievement', 'borders', 'on', 'the', 'ridiculous', '.']
# ['This', 'is', 'the', 'year', 'home', 'runs', 'ranged', 'from', 'the', 'sublime', 'to', 'the', 'ridiculous', '.']
# ['His', 'addle-brained', 'knight-errant', ',', 'self-appointed', 'to', 'the', 'ridiculous', 'position', 'in', 'an', 'age', 'when', 'armor', 'had', 'already', 'been', 'relegated', 'to', 'museums', 'and', 'the', 'chivalrous', 'code', 'of', 'knight-errantry', 'had', 'become', 'a', 'joke', ',', 'is', ',', 'as', 'Cervantes', 'no', 'doubt', 'intended', ',', 'a', 'gaunt', 'but', 'gracious', 'symbol', 'of', 'good', ',', 'moving', 'soberly', 'and', 'sincerely', 'in', 'a', 'world', 'of', 'cynics', ',', 'hypocrites', 'and', 'rogues', '.']
# ['his', 'end', 'is', 'ridiculous', 'and', 'trivial', '.']
# ['Hieronymus', ',', 'like', 'Piepsam', ',', 'makes', 'his', 'protest', 'quite', 'in', 'vain', ',', 'and', 'his', 'rejection', ',', 'though', 'not', 'fatal', ',', 'is', 'ridiculous', 'and', 'humiliating', ';', ';']
# ['After', 'the', 'collapse', 'of', 'that', 'desperate', 'and', 'ill-fated', 'campaign', 'the', 'character', 'of', 'the', 'king', 'degenerated', 'for', 'a', 'time', 'into', 'a', 'futility', 'that', 'was', 'not', 'merely', 'pitiable', 'but', 'often', 'ridiculous', '.']
# ['I', 'worked', 'for', 'a', 'day', 'on', 'this', 'plainly', 'ridiculous', 'assignment', 'and', 'consulted', 'several', 'of', 'my', 'own', 'well-informed', 'sources', '.']
# ['The', 'result', 'was', 'that', 'I', 'found', 'myself', 'in', 'the', 'ridiculous', 'position', 'of', 'having', 'made', 'a', 'formal', 'engagement', 'by', 'letter', 'for', 'the', 'next', 'week', ',', 'only', 'two', 'days', 'before', 'my', 'departure', 'from', 'London', '.']
# ['It', 'was', 'a', 'ridiculous', 'situation', 'and', 'Rector', 'knew', 'it', ',', 'for', 'Hino', ',', 'frankly', 'partisan', ',', 'openly', 'gregarious', ',', 'would', 'make', 'a', 'poor', 'espionage', 'agent', '.']
# ['Even', 'then', ',', 'as', 'you', 'go', 'into', 'the', 'house', 'oppressed', 'by', 'the', 'knowledge', 'that', 'something', 'is', 'cooking', 'and', 'that', 'your', 'house', 'has', 'passed', 'under', 'this', 'unaccountable', ',', 'official', 'control', ',', 'could', 'you', 'go', 'on', 'forgetting', 'that', 'you', 'still', 'had', 'that', 'ridiculous', 'hat', 'on', 'your', 'head', 'and', 'you', 'were', 'still', 'carrying', 'that', 'childish', 'horn', 'in', 'your', 'hand', '?', '?']
# ['The', 'quarrel', 'ended', 'in', 'a', 'ridiculous', 'draw', ',', 'but', 'I', 'must', 'tell', 'you', 'about', 'it', '.']
# ['That', 'battle', 'scene', ',', 'ridiculous', 'as', 'it', 'was', ',', 'remained', 'in', 'my', 'mind', '.']
# ['Almost', 'too', 'smoothly', ',', 'I', 'found', 'myself', 'thinking', ',', 'and', 'then', 'told', 'myself', 'that', 'was', 'ridiculous', '.']
# ['As', 'he', 'lowered', 'himself', 'on', 'the', 'chair', 'behind', 'his', 'desk', 'I', 'wondered', 'what', 'this', 'dapper', ',', 'slightly', 'ridiculous', 'man', 'could', 'possibly', 'have', 'to', 'do', 'with', 'the', 'workings', 'of', 'the', 'hall', '.']
# ['A', 'few', 'days', 'ago', ',', 'she', 'would', 'have', 'thought', 'such', 'an', 'expedition', 'as', 'this', 'utterly', 'ridiculous', ';', ';']
# ['``', 'I', 'wish', 'I', "wasn't", 'wearing', 'this', 'ridiculous', 'costume', ',', 'and', 'that', 'we', 'could', 'go', 'to', 'a', 'theater', 'together', ',', 'or', 'a', 'nice', 'restaurant', ',', 'forget', 'we', 'knew', "''", 'He', 'stopped', 'speaking', '.']
# ['But', 'that', 'was', 'ridiculous', ',', 'of', 'course', '.']
# ['he', 'would', 'cut', 'a', 'supremely', 'ridiculous', 'figure', '.']

# %% [markdown]
# For many applications, you want to be able to iterate over the documents. Using NLTK, this is a two step process: first, you to get a list of the files using the `fileids()` method. Then you call the appropriate method from those mentioned above with the fileid you want as the argument.

# %%
for filename in brown.fileids():
    print(brown.words(filename)[:5])
# Out:
# ['The', 'Fulton', 'County', 'Grand', 'Jury']
# ['Austin', ',', 'Texas', '--', 'Committee']
# ['Several', 'defendants', 'in', 'the', 'Summerdale']
# ['Oslo', 'The', 'most', 'positive', 'element']
# ['East', 'Providence', 'should', 'organize', 'its']
# ['Plainfield', '--', 'James', 'P.', 'Mitchell']
# ['Resentment', 'welled', 'up', 'yesterday', 'among']
# ['Appointment', 'of', 'William', 'S.', 'Pfaff']
# ['City', 'Controller', 'Alexander', 'Hemphill', 'charged']
# ['Vincent', 'G.', 'Ierulli', 'has', 'been']
# ['Miami', ',', 'Fla.', ',', 'March']
# ['Austin', ',', 'Texas', '--', 'A']
# ['Rookie', 'Ron', 'Nischwitz', 'continued', 'his']
# ['Philadelphia', ',', 'Jan.', '23', '--']
# ['If', 'the', 'Cardinals', 'heed', 'Manager']
# ['Romantic', 'news', 'concerns', 'Mrs.', 'Joan']
# ['After', 'being', 'closed', 'for', 'seven']
# ['``', 'A', 'Night', 'in', 'New']
# ['The', 'Baltimore', 'and', 'Ohio', 'Railroad']
# ['London', ',', 'Feb.', '9', '--']
# ['St.', 'Johns', ',', 'Mich.', ',']
# ['Emory', "University's", 'Board', 'of', 'Trustees']
# ['Salem', '(', 'special', ')', '--']
# ['About', '70', 'North', 'Providence', 'taxpayers']
# ['Asilomar', ',', 'March', '26', 'Vast']
# ['Probably', 'the', 'hottest', 'thing', 'that']
# ['Santa', 'Barbara', '--', '``', 'The']
# ['Elburn', ',', 'Ill.', '--', 'Farm']
# ['Greer', 'Garson', ',', 'world-famous', 'star']
# ['A', 'cookie', 'with', 'caramel', 'filling']
# ['Hotel', "Escape's", 'Bonanza', 'room', 'has']
# ['Enrique', 'Jorda', ',', 'conductor', 'and']
# ['At', 'last', 'the', 'White', 'House']
# ['For', 'crucial', 'encounter', 'One', 'of']
# ['There', 'are', ',', 'so', 'my']
# ['Sen.', 'John', 'L.', 'McClellan', 'of']
# ['The', 'nation', 'the', 'three-front', 'war']
# ['The', 'Masters', 'golf', 'tournament', 'proved']
# ['When', 'Mickey', 'Charles', 'Mantle', ',']
# ['Into', 'Washington', 'on', 'President-elect', 'John']
# ['A', 'philosopher', 'may', 'point', 'out']
# ['The', 'presidency', ':', 'talking', 'and']
# ['Holders', 'of', 'toll-road', 'bonds', 'are']
# ['Every', 'library', 'borrower', ',', 'or']
# ['Assembly', 'session', 'brought', 'much', 'good']
# ['Must', 'Berlin', 'remain', 'divided', '?']
# ['A', 'good', 'man', 'departs', '.']
# ['A', 'shock', 'wave', 'from', 'Africa']
# ['Help', 'when', 'needed', 'If', 'the']
# ['The', 'study', 'of', 'the', 'St.']
# ['The', "U.N.'s", "'", 'gravest', 'crisis']
# ['Old', ',', 'tired', ',', 'trembling']
# ['Mr.', 'Podger', 'always', 'particularly', 'enjoyed']
# ['Miami', ',', 'Fla.', ',', 'March']
# ['California', 'Democrats', 'this', 'weekend', 'will']
# ['Sing', "Sing's", 'prisoner', 'strike', 'was']
# ['Sizzling', 'temperatures', 'and', 'hot', 'summer']
# ['This', 'is', 'the', 'period', 'during']
# ['The', 'Providence', 'Journal', 'editorial', '(']
# ['``', 'A', 'lousy', 'job', "''"]
# ['``', 'Workers', 'of', 'the', 'party']
# ['For', 'a', 'neutral', 'Germany', 'Soviets']
# ['Ghost', 'town', '?', '?', 'To']
# ['Escalation', 'unto', 'death', 'The', 'nuclear']
# ['All', 'false', 'gods', 'resemble', 'Moloch']
# ['Resuming', 'atmospheric', 'tests', 'One', 'of']
# ['Everywhere', 'I', 'went', 'in', 'Formosa']
# ['Broadway', 'the', 'unoriginals', 'To', 'write']
# ['The', 'most', 'surprising', 'thing', 'about']
# ['Tenure', 'as', 'criterion', 'I', 'would']
# ['Confrontation', 'It', 'seems', 'to', 'me']
# ['It', 'is', 'not', 'news', 'that']
# ['Television', 'has', 'yet', 'to', 'work']
# ['Francois', "D'Albert", ',', 'Hungarian-born', 'violinist']
# ['The', 'Theatre-by-the-Sea', ',', 'Matunuck', ',']
# ['The', 'superb', 'intellectual', 'and', 'spiritual']
# ['George', "Kennan's", 'account', 'of', 'relations']
# ['Some', 'of', 'the', 'New', 'York']
# ['Had', 'a', 'funny', 'experience', 'at']
# ['Murray', 'Louis', 'and', 'his', 'dance']
# ['Ring', 'Of', 'Bright', 'Water', ',']
# ['Mischa', 'Elman', 'shared', 'last', "night's"]
# ['Radio', 'is', 'easily', 'outdistancing', 'television']
# ['A', 'tribe', 'in', 'ancient', 'India']
# ['Elisabeth', 'Schwarzkopf', 'sang', 'so', 'magnificently']
# ['As', 'autumn', 'starts', 'its', 'annual']
# ['A', 'year', 'ago', 'it', 'was']
# ['The', 'reading', 'public', ',', 'the']
# ['As', 'a', 'result', ',', 'although']
# ['If', 'the', 'content', 'of', 'faith']
# ['One', 'hundred', 'years', 'ago', 'there']
# ['The', 'death', 'of', 'a', 'man']
# ['Furthermore', ',', 'as', 'an', 'encouragement']
# ['I', 'have', ',', 'within', 'the']
# ['``', 'The', 'Lord', 'is', 'my']
# ['But', ',', 'again', ',', 'we']
# ['Few', 'persons', 'who', 'join', 'the']
# ['Men', 'need', 'unity', 'and', 'they']
# ['When', 'they', 'say', 'that', 'under']
# ['Much', 'more', 'than', 'shelter', ',']
# ['If', 'we', 'look', 'about', 'the']
# ['To', 'what', 'extent', 'and', 'in']
# ['Individuals', 'possessing', 'unusual', 'gifts', 'and']
# ['Pope', 'Leo', '13', ',', 'on']
# ['I', 'am', 'a', 'magazine', ';']
# ['Too', 'often', 'a', 'beginning', 'bodybuilder']
# ['The', 'most', 'beautiful', 'bed', 'of']
# ['Five', ',', 'four', ',', 'three']
# ['The', 'lyric', 'beauties', 'of', "Schubert's"]
# ['At', 'the', 'Westminster', 'KC', 'Dog']
# ['At', 'one', 'time', ',', 'to']
# ['The', 'design', 'of', 'a', 'mechanical']
# ['Scientists', 'say', 'that', 'the', 'world']
# ['Orlando', ',', 'Fla.', ',', 'Feb.']
# ['The', 'average', 'reader', 'of', 'this']
# ['Livery', 'stable', '--', 'J.', 'Vernon']
# ['Those', 'who', 'have', 'never', 'traveled']
# ['Built', 'upon', 'seven', 'hills', ',']
# ['(', 'Do', 'start', 'fires', 'one']
# ['Note', ':', 'Directions', 'are', 'written']
# ['Hotei', 'is', '23', 'feet', 'long']
# ['You', 'can', 'build', 'this', 'vacation']
# ['The', 'old-time', 'bridges', 'over', 'the']
# ['It', 'is', 'a', 'good', 'eight']
# ['Draw', 'a', 'line', 'across', 'the']
# ['Most', 'recreation', 'work', 'calls', 'for']
# ['Your', 'invitation', 'to', 'write', 'about']
# ['Roy', 'Mason', 'is', 'essentially', 'a']
# ['The', 'Russian', 'gymnasts', 'beat', 'the']
# ['Every', 'taxpayer', 'is', 'well', 'aware']
# ["Oersted's", 'boyhood', 'represented', 'a', 'minimal']
# ['Knowing', 'specifically', 'what', 'the', 'many']
# ['Marketing', 'in', 'the', 'new', 'decade']
# ['The', 'controversy', 'of', 'the', 'last']
# ['General', 'How', 'long', 'has', 'it']
# ['The', 'long', 'and', 'ever-increasing', 'column']
# ['Throughout', 'history', ',', 'the', 'man']
# ['Sixty', 'miles', 'north', 'of', 'New']
# ['In', 'the', 'period', 'since', 'the']
# ['New', 'rule', 'no.', '2', ':']
# ['There', 'comes', 'a', 'time', 'in']
# ['In', 'American', 'romance', ',', 'almost']
# ['She', 'was', 'just', 'another', 'freighter']
# ['There', 'is', 'a', 'pause', 'in']
# ['``', 'The', 'food', 'is', 'wonderful']
# ['Buffeted', 'by', 'swirling', 'winds', ',']
# ['Are', 'you', 'retiring', 'now', '?']
# ['Some', 'recent', 'writings', 'assume', 'that']
# ['In', 'tradition', 'and', 'in', 'poetry']
# ['She', 'gave', 'herself', 'a', 'title']
# ['Franklin', 'D.', 'Lee', 'proved', 'a']
# ['Ten-year-old', 'Richard', 'Stewart', 'had', 'been']
# ['From', 'time', 'to', 'time', 'the']
# ['Farming', 'is', 'confining', '.', 'The']
# ['Everyone', 'with', 'a', 'personal', 'or']
# ['In', 'Poughkeepsie', ',', 'N.Y.', ',']
# ['On', 'April', '17', ',', '1610']
# ['Thomas', 'Douglas', ',', 'fifth', 'Earl']
# ['The', 'letters', 'of', 'the', 'common']
# ['The', 'popularity', 'of', 'folklore', 'in']
# ['As', 'part', 'of', 'the', 'same']
# ['A', 'tsunami', 'may', 'be', 'started']
# ['In', "Ireland's", 'County', 'Limerick', ',']
# ['I', 'do', 'not', 'mean', 'to']
# ['The', 'first', 'rattle', 'of', 'the']
# ['My', 'interviews', 'with', 'teen-agers', 'confirmed']
# ['This', 'should', 'be', 'used', 'frequently']
# ['Except', 'for', 'the', 'wine', 'waiter']
# ['Giffen', 'replied', 'punctually', 'and', 'enthusiastically']
# ['But', 'certainly', 'the', 'New', 'Frontier']
# ['Surrounded', 'by', 'ancient', 'elms', ',']
# ['The', 'person', 'who', 'left', 'the']
# ['Her', 'father', ',', 'James', 'Upton']
# ['In', 'a', 'few', 'school', 'districts']
# ['The', 'soybean', 'seed', 'is', 'the']
# ['To', 'hold', 'a', 'herd', 'of']
# ['It', 'was', 'John', 'who', 'found']
# ['The', 'missionary', 'obligation', 'to', 'proclaim']
# ['Yet', 'a', 'crowd', 'came', 'out']
# ['This', 'conclusion', 'is', 'dependent', 'on']
# ['In', 'the', 'final', 'accounting', ',']
# ['A', 'little', 'farther', 'along', 'the']
# ['Rare', ',', 'indeed', ',', 'is']
# ['Color', 'was', 'delayed', 'until', '1935']
# ['In', 'general', ',', 'religious', 'interest']
# ['With', 'capital', 'largely', 'squandered', ',']
# ['They', 'would', 'not', 'be', 'pleased']
# ['The', 'deep', 'water', 'is', 'used']
# ['The', 'achievement', 'of', 'the', 'desegregation']
# ['Northern', 'liberals', 'are', 'the', 'chief']
# ['In', 'the', 'past', ',', 'the']
# ['Can', 'thermonuclear', 'war', 'be', 'set']
# ['Suddenly', ',', 'however', ',', 'their']
# ['It', 'was', 'a', 'fortunate', 'time']
# ['Die', 'Frist', 'ist', 'um', ',']
# ['Once', 'again', ',', 'as', 'in']
# ['Tobacco', 'Road', 'is', 'dead', '.']
# ['Another', 'element', 'to', 'concern', 'the']
# ['The', 'North', 'and', 'the', 'South']
# ['As', 'cells', 'coalesced', 'into', 'organisms']
# ['Nothing', 'like', 'Godot', ',', 'he']
# ['Even', 'Hemingway', ',', 'for', 'all']
# ['There', 'were', 'fences', 'in', 'the']
# ['It', 'is', 'worth', 'dwelling', 'in']
# ['The', '``', 'reality', "''", 'to']
# ['After', 'only', 'eighteen', 'years', 'of']
# ['Among', 'the', 'recipients', 'of', 'the']
# ['Today', 'the', 'private', 'detective', 'will']
# ['It', 'will', 'be', 'shown', 'that']
# ['American', 'democratic', 'thought', ',', 'pointed']
# ['Does', 'our', 'society', 'have', 'a']
# ['During', 'the', 'last', 'years', 'of']
# ['The', "President's", 'personality', 'would', 'have']
# ['For', 'this', 'change', 'is', 'not']
# ['All', 'of', 'which', 'brings', 'up']
# ['In', 'recollection', 'he', 'has', 'said']
# ['Important', 'as', 'was', 'Mr.', "O'Donnell's"]
# ['Some', 'years', 'ago', 'Julian', 'Huxley']
# ['Copernicus', 'did', 'not', 'question', 'it']
# ["Henrietta's", 'feeling', 'of', 'identity', 'with']
# ['This', 'time', 'he', 'was', 'making']
# ['More', 'likely', ',', 'you', 'simply']
# ['With', 'each', 'song', 'he', 'gave']
# ['The', 'United', 'States', 'is', 'always']
# ['The', 'group', ',', 'upon', 'the']
# ['Fortunately', 'the', 'hole', 'was', 'found']
# ['She', 'describes', ',', 'first', ',']
# ['When', 'Harold', 'Arlen', 'returned', 'to']
# ['I', 'feel', 'obliged', 'to', 'describe']
# ['If', 'she', 'were', 'not', 'at']
# ['Impressive', 'as', 'this', 'enumeration', 'is']
# ['Two', 'facets', 'of', 'this', 'aspect']
# ['The', 'late', 'R.', 'G.', 'Collingwood']
# ['``', 'Suppose', 'you', 'take', 'Mr.']
# ["Trevelyan's", 'Liberalism', 'was', 'above', 'all']
# ['I', 'stood', 'on', 'a', 'table']
# ['He', 'remembered', 'every', 'detail', 'of']
# ['In', 'one', 'of', 'the', 'very']
# ['As', 'he', 'had', 'done', 'on']
# ['Mando', ',', 'pleading', 'her', 'cause']
# ['``', 'Let', 'him', 'become', 'honest']
# ['Samuel', 'Gorton', ',', 'founder', 'of']
# ['When', 'Fred', 'wheeled', 'him', 'back']
# ['It', 'was', 'not', 'until', 'we']
# ['Criticism', 'is', 'as', 'old', 'as']
# ['But', 'it', 'would', 'not', 'be']
# ['From', 'New', 'Jersey', ',', 'Morgan']
# ['For', 'by', 'now', 'the', 'original']
# ['It', 'usually', 'turned', 'out', 'well']
# ['The', 'turn', 'of', 'the', 'century']
# ['To', 'do', 'so', ',', 'something']
# ['In', 'the', 'imagination', 'of', 'the']
# ['The', 'Bishop', 'of', 'Gloucester', 'described']
# ['The', 'fall', 'of', 'Rome', ',']
# ['Stephens', 'had', 'written', 'his', 'classic']
# ['He', 'looked', 'at', 'her', 'as']
# ['From', '1613', 'on', ',', 'if']
# ['Writers', 'of', 'this', 'class', 'of']
# ['We', 'often', 'say', 'of', 'a']
# ['For', 'here', 'if', 'anywhere', 'in']
# ['In', 'a', 'pessimistic', 'assessment', 'of']
# ['The', 'recent', 'experiments', 'in', 'the']
# ['Let', 'us', 'see', 'just', 'how']
# ['There', 'had', 'been', 'signs', 'and']
# ['The', 'Office', 'of', 'Business', 'Economics']
# ['In', 'most', 'of', 'the', 'less']
# ['You', 'have', 'heard', 'him', 'tell']
# ['Origin', 'of', 'state', 'automobile', 'practices']
# ['The', 'Rhode', 'Island', 'property', 'tax']
# ['Local', "industry's", 'investment', 'in', 'Rhode']
# ['Special', 'districts', 'in', 'Rhode', 'island']
# ['Rhode', 'Island', 'Heritage', 'Week', 'proclamation']
# ['Be', 'it', 'enacted', 'by', 'the']
# ['In', 'the', 'same', 'period', ',']
# ['Another', 'recent', 'achievement', 'was', 'the']
# ['(', 'E', ')', 'In', 'addition']
# ['Mr.', 'Dooley', '.', 'Mr.', 'Speaker']
# ['From', 'its', 'inception', 'in', '1920']
# ['At', 'the', 'entrance', 'side', 'of']
# ['A', 'former', 'Du', 'Pont', 'official']
# ['It', 'is', 'not', 'a', 'medieval']
# ['Foreign', 'policy', 'in', 'its', 'total']
# ['While', 'there', 'should', 'be', 'no']
# ['Wildlife', 'habitat', 'resources', 'In', '1960']
# ['Strategy', 'and', 'tactics', 'of', 'the']
# ['Purchase', 'authorizations', 'will', 'include', 'provisions']
# ['This', 'broad', 'delegation', 'leaves', 'within']
# ['If', 'you', 'elect', 'to', 'use']
# ['The', 'one-', 'or', 'two-season', 'hunt']
# ['When', 'the', 'Brown', '&', 'Sharpe']
# ['Sales', 'and', 'net', 'income', 'for']
# ['Following', 'the', 'term', 'of', 'service']
# ['In', 'recent', 'months', ',', 'much']
# ['Between', 'meetings', 'he', 'helps', 'the']
# ['1', '.', 'Introduction', 'It', 'has']
# ['Abstract', 'Experiments', 'were', 'made', 'on']
# ['A', 'band', 'viscometer', 'is', 'shown']
# ['A', 'proton', 'magnetic', 'resonance', 'study']
# ['Polyphosphates', 'gave', 'renewed', 'life', 'to']
# ['The', 'thermal', 'exchange', 'of', 'chlorine']
# ['The', 'Poynting-Robertson', 'effect', '(', 'Robertson']
# ['Biological', 'warfare', 'Biological', 'warfare', 'is']
# ['A', 'variety', 'of', 'techniques', 'have']
# ['Apart', 'from', 'the', 'honeybee', ',']
# ['Many', 'other', '(', 'probably', 'nearly']
# ['The', 'bronchus', 'and', 'pulmonary', 'artery']
# ['Some', 'of', 'the', 'features', 'of']
# ['Interestingly', 'enough', ',', 'the', 'effect']
# ['Introduction', 'Muscle', 'weakness', 'is', 'now']
# ['Purification', 'of', 'the', 'conjugates', 'In']
# ['Since', 'emotional', 'reactions', 'in', 'the']
# ['6.4', '.', 'The', 'primary', 'decomposition']
# ['7-1', '.', 'Examples', 'of', 'binomial']
# ['Consider', 'a', 'simple', ',', 'closed']
# ['Introduction', '.', 'In', '1', 'we']
# ['These', 'societies', 'can', 'expect', 'to']
# ['2', ':', ':', 'Some', 'of']
# ['Overwhelmed', 'with', 'the', 'care', 'of']
# ['Sentiment', '.', 'Tension', 'management', 'and']
# ['A', 'royal', 'decree', 'issued', 'in']
# ['With', 'this', 'evidence', 'in', 'mind']
# ['Thus', 'it', 'is', 'reasonable', 'to']
# ['Control', 'of', 'socioeconomic', 'status', 'It']
# ['Analysis', 'Analysis', 'means', 'the', 'evaluation']
# ['It', 'is', 'not', 'easy', 'for']
# ['The', 'many', 'linguistic', 'techniques', 'for']
# ['In', 'sentences', ',', 'patterns', 'of']
# ['It', 'is', 'obvious', 'enough', 'that']
# ['There', 'are', 'more', 'stems', 'per']
# ['Doubtless', 'it', 'was', 'inevitable', 'that']
# ['An', 'analysis', 'of', 'the', 'election']
# ['Unemployed', 'older', 'workers', 'who', 'have']
# ['But', 'briefly', ',', 'the', 'topping']
# ['In', 'assessing', 'the', 'outlook', 'for']
# ['Wage-price', 'policies', 'of', 'industry', 'are']
# ['In', 'the', 'century', 'from', '1815']
# ['Mr.', 'Justice', 'Black', 'was', 'one']
# ['How', 'else', 'can', 'one', 'explain']
# ['A', '.', 'Reasons', 'for', 'selecting']
# ['The', 'vast', 'Central', 'Valley', 'of']
# ['9', '.', 'Martin', 'and', 'Stendler']
# ['The', 'Summary', 'Report', 'On', 'Desegregation']
# ['The', 'next', 'question', 'is', 'whether']
# ['Unfortunately', ',', 'however', ',', 'and']
# ['The', 'preconditions', 'of', 'sociology', 'have']
# ['But', 'neither', 'was', 'the', 'statement']
# ['The', 'injured', 'German', 'veteran', 'was']
# ['Whenever', 'artists', ',', 'indeed', ',']
# ['Cook', 'had', 'discovered', 'a', 'beef']
# ['The', 'plant', 'was', 'located', 'west']
# ['Some', 'who', 'have', 'written', 'on']
# ['During', 'the', 'Dorr', 'trial', 'the']
# ['Rather', 'than', 'being', 'deceived', ',']
# ['Los', 'Angeles', 'in', '1957', 'finally']
# ['Before', 'losing', 'itself', 'in', 'the']
# ['Those', 'whom', 'I', 'wish', 'to']
# ['The', 'Sane', 'Society', 'is', 'an']
# ['If', 'one', 'characteristic', 'distinguishes', 'Boris']
# ['So', 'far', 'these', 'remarks', ',']
# ['Critically', 'invisible', ',', 'modern', 'revolt']
# ['Anglo-Saxon', 'and', 'Greek', 'epic', 'each']
# ['Recent', 'criticism', 'of', 'Great', 'Expectations']
# ['The', 'following', 'items', 'may', 'be']
# ['In', 'the', 'Midwest', ',', 'oxidation']
# ['Thus', ',', 'the', 'three', 'main']
# ['Two', 'metabolites', '(', '1', ',']
# ['Organization', ':', 'In', 'this', 'publication']
# ['Because', 'individual', 'classes', 'of', 'foods']
# ['Furthermore', ',', 'it', 'has', 'made']
# ['Within', 'only', 'a', 'few', 'years']
# ['Temperature', 'of', 'the', 'wash', 'and']
# ['High-gain', ',', 'photoelectronic', 'image', 'intensification']
# ['The', 'set', 'of', 'all', 'decisions']
# ['A', 'gyro-stabilized', 'platform', 'system', ',']
# ['Thirty-three', 'Scotty', 'did', 'not', 'go']
# ['Where', 'their', 'sharp', 'edges', 'seemed']
# ['Mickie', 'sat', 'over', 'his', 'second']
# ['The', 'Bishop', 'looked', 'at', 'him']
# ['Payne', 'dismounted', 'in', 'Madison', 'Place']
# ['With', 'a', 'sneer', ',', 'the']
# ['If', 'the', 'crummy', 'bastard', 'could']
# ['Rousseau', 'is', 'so', 'persuasive', 'that']
# ['It', 'was', 'the', 'first', 'time']
# ['That', 'summer', 'the', 'gambling', 'houses']
# ['Standing', 'in', 'the', 'shelter', 'of']
# ['She', 'was', 'a', 'child', 'too']
# ['In', 'the', 'dim', 'underwater', 'light']
# ['He', 'brought', 'with', 'him', 'a']
# ['Beth', 'was', 'very', 'still', 'and']
# ['The', 'red', 'glow', 'from', 'the']
# ['Burly', 'leathered', 'men', 'and', 'wrinkled']
# ['She', 'was', 'getting', 'real', 'dramatic']
# ['There', 'was', 'one', 'fact', 'which']
# ['She', 'concluded', 'by', 'asking', 'him']
# ['Beckworth', 'handed', 'the', 'pass', 'to']
# ['I', 'would', 'not', 'want', 'to']
# ['It', 'was', 'not', 'as', 'though']
# ['His', 'eyes', 'were', 'old', 'and']
# ['He', 'was', 'in', 'his', 'mid-fifties']
# ['But', 'they', 'all', 'said', ',']
# ['``', 'But', 'tell', 'me', ',']
# ['Going', 'downstairs', 'with', 'the', 'tray']
# ['Was', 'it', 'love', '?', '?']
# ['There', 'were', 'thirty-eight', 'patients', 'on']
# ['I', 'was', 'giving', 'the', 'parked']
# ['The', 'fat', 'man', 'said', ',']
# ['His', 'jowls', 'were', 'spiked', 'by']
# ['Then', 'he', 'turned', 'the', 'telephone']
# ['Eight', ',', 'nine', 'steps', 'above']
# ['He', 'put', 'in', 'a', 'call']
# ['``', 'Well', "''", '--', 'said']
# ["Maude's", 'long', 'nose', 'unexpectedly', 'wrinkled']
# ['``', 'Not', 'since', 'last', 'night']
# ['``', 'Right', "''", ',', 'said']
# ['Andy', 'did', 'not', 'see', 'the']
# ['His', 'son', 'watched', 'until', 'he']
# ['A', 'man', 'with', 'a', 'sketch']
# ['``', 'Through', 'a', 'door', 'conveniently']
# ['``', 'Dammit', ',', 'Phil', ',']
# ['The', 'safe', 'at', 'Ingleside', 'District']
# ['``', 'She', 'says', 'she', 'has']
# ['Slowly', 'he', 'pulled', 'out', 'the']
# ['Harbor', 'Point', 'sticks', 'out', 'into']
# ['But', 'the', 'police', 'have', 'dropped']
# ['In', 'good', 'time', 'I', 'shall']
# ["That's", 'what', 'the', 'man', 'had']
# ['About', 'halfway', 'back', 'Pops', 'groped']
# ['Now', 'that', 'he', 'knew', 'himself']
# ['The', 'expense', 'and', 'time', 'involved']
# ['This', 'was', 'not', ',', 'for']
# ['Ryan', 'hefted', 'his', 'bulk', 'up']
# ['She', 'lived', 'and', 'was', 'given']
# ['It', 'would', 'have', 'killed', 'you']
# ['Dan', 'Morgan', 'told', 'himself', 'he']
# ['Gavin', 'paused', 'wearily', '.', '``']
# ['The', 'sentry', 'was', 'not', 'dead']
# ['``', 'So', 'it', "wasn't", 'the']
# ['She', 'was', 'carrying', 'a', 'quirt']
# ['Such', 'was', 'my', 'state', 'of']
# ['The', 'flat', ',', 'hard', 'cap']
# ['If', 'she', 'sensed', 'any', 'unusual']
# ['Miraculously', ',', 'she', 'found', 'exactly']
# ['The', 'Brannon', 'outfit', '--', 'known']
# ['The', 'author', 'of', 'the', 'anonymous']
# ['When', 'several', 'minutes', 'had', 'passed']
# ['Over', 'his', 'shoulder', 'he', 'could']
# ['While', 'no', 'larger', 'than', 'Dutch']
# ['Early', 'in', 'November', 'the', 'clouds']
# ['Over', 'the', 'rattling', 'of', 'fenders']
# ['I', 'guided', 'her', 'to', 'the']
# ['Too', 'many', 'people', 'think', 'that']
# ['He', 'had', 'better', 'write', 'a']
# ['They', 'were', 'west', 'of', 'the']
# ['Sulphur', ',', 'oil', ',', 'and']
# ['``', 'I', 'guess', 'he', 'spent']
# ['Then', 'he', 'calmly', 'and', 'carefully']
# ['Now', ',', 'the', 'next', 'morning']
# ['Early', 'that', 'day', 'Matsuo', 'saw']
# ['Chairs', 'scraped', 'back', 'and', 'customers']
# ['For', 'several', 'months', 'now', ',']
# ['On', 'the', 'fringe', 'of', 'the']
# ['``', 'Bastards', "''", ',', 'he']
# ['They', 'neither', 'liked', 'nor', 'disliked']
# ['People', 'came', 'in', 'and', 'out']
# ['``', 'Thrifty', 'of', 'her', 'to']
# ['``', 'He', 'must', 'have', 'forgiven']
# ['The', 'Momoyama', 'family', 'had', 'come']
# ['How', ',', 'he', 'wondered', ',']
# ['Spencer', 'said', 'nothing', '.', '``']
# ['Rachel', 'steered', 'me', 'along', 'toward']
# ['``', 'And', "I'll", 'take', 'you']
# ['Among', 'us', ',', 'we', 'three']
# ['Such', 'a', 'little', 'thing', 'to']
# ['``', 'I', 'had', 'a', 'rather']
# ['But', 'one', 'night', 'Dookiyoon', 'moved']
# ['She', 'was', 'moving', 'through', 'a']
# ['``', 'They', 'make', 'us', 'conformists']
# ['Unimpressed', ',', 'the', 'dog', 'plopped']
# ['When', 'Bobbie', 'Evans', 'smashed', 'up']
# ['She', 'called', 'then', 'to', 'say']
# ['I', "don't", 'really', 'believe', 'in']
# ['I', 'was', 'slowly', 'swimming', 'down']
# ['Two', 'letters', 'had', 'arrived', 'for']
# ['I', 'knew', 'it', 'as', 'surely']
# ['Under', 'normal', 'circumstances', ',', 'he']
# ['There', 'was', 'a', 'crowd', 'in']
# ["Richard's", 'next', 'interest', 'seemed', 'the']
# ['I', 'was', 'thinking', 'of', 'the']
# ['Cady', "didn't", 'come', 'unglued', 'easily']
# ['Martin', 'felt', 'it', 'was', 'incredible']
# ['``', 'Good', 'old', 'A-Z', "''"]
# ['It', 'was', 'among', 'these', 'that']
# ['I', 'realized', 'that', 'Hamlet', 'was']
# ['Needless', 'to', 'say', ',', 'I']
# ['Up', 'to', 'date', ',', 'however']
# ['Ambiguity', 'Nothing', 'in', 'English', 'has']
# ['I', 'called', 'the', 'other', 'afternoon']
# ['One', 'day', ',', 'the', 'children']
# ['Pueri', 'aquam', 'de', 'silvas', 'ad']
# ['Dear', 'Sirs', ':', 'Let', 'me']

# %% [markdown]
# ## Annotations

# %% [markdown]
# Nearly all the corpora in NLTK have some kind of annotation associated with them. One common annotation is some kind of label for documents in the corpus. In the Brown, for instance, the label is associated with the genre, and for the Movie Review corpus it is the polarity (positive or negative) of the review. A list of categories is available using the `categories()` method

# %%
print(brown.categories())
print(movie_reviews.categories())
# Out:
# ['adventure', 'belles_lettres', 'editorial', 'fiction', 'government', 'hobbies', 'humor', 'learned', 'lore', 'mystery', 'news', 'religion', 'reviews', 'romance', 'science_fiction']
# ['neg', 'pos']

# %% [markdown]
# In order to get text from a particular category, you can use the `categories` keyword for `words()`/`sents()/...`.

# %%
for sent in brown.sents(categories="religion")[:5]:
    print(sent)
# Out:
# ['As', 'a', 'result', ',', 'although', 'we', 'still', 'make', 'use', 'of', 'this', 'distinction', ',', 'there', 'is', 'much', 'confusion', 'as', 'to', 'the', 'meaning', 'of', 'the', 'basic', 'terms', 'employed', '.']
# ['Just', 'what', 'is', 'meant', 'by', '``', 'spirit', "''", 'and', 'by', '``', 'matter', "''", '?', '?']
# ['The', 'terms', 'are', 'generally', 'taken', 'for', 'granted', 'as', 'though', 'they', 'referred', 'to', 'direct', 'and', 'axiomatic', 'elements', 'in', 'the', 'common', 'experience', 'of', 'all', '.']
# ['Yet', 'in', 'the', 'contemporary', 'context', 'this', 'is', 'precisely', 'what', 'one', 'must', 'not', 'do', '.']
# ['For', 'in', 'the', 'modern', 'world', 'neither', '``', 'spirit', "''", 'nor', '``', 'matter', "''", 'refer', 'to', 'any', 'generally', 'agreed-upon', 'elements', 'of', 'experience', '.']

# %% [markdown]
# If you want to iterate over documents, you can also get fileids for that category using the category as an argument to fileids, and then  use `words()`/`sents()`

# %%
for filename in brown.fileids("religion"):
    print(brown.words(filename))
# Out:
# ['As', 'a', 'result', ',', 'although', 'we', 'still', ...]
# ['If', 'the', 'content', 'of', 'faith', 'is', 'to', ...]
# ['One', 'hundred', 'years', 'ago', 'there', 'existed', ...]
# ['The', 'death', 'of', 'a', 'man', 'is', 'unique', ',', ...]
# ['Furthermore', ',', 'as', 'an', 'encouragement', 'to', ...]
# ['I', 'have', ',', 'within', 'the', 'past', 'fifty', ...]
# ['``', 'The', 'Lord', 'is', 'my', 'light', 'and', 'my', ...]
# ['But', ',', 'again', ',', 'we', 'have', 'no', 'real', ...]
# ['Few', 'persons', 'who', 'join', 'the', 'Church', ...]
# ['Men', 'need', 'unity', 'and', 'they', 'need', 'God', ...]
# ['When', 'they', 'say', 'that', 'under', 'no', ...]
# ['Much', 'more', 'than', 'shelter', ',', 'housing', ...]
# ['If', 'we', 'look', 'about', 'the', 'world', 'today', ...]
# ['To', 'what', 'extent', 'and', 'in', 'what', 'ways', ...]
# ['Individuals', 'possessing', 'unusual', 'gifts', ...]
# ['Pope', 'Leo', '13', ',', 'on', 'the', '13th', 'day', ...]
# ['I', 'am', 'a', 'magazine', ';', ';', 'my', 'name', ...]

# %% [markdown]
# Or you can iterate through all the texts and look up the category for a particular fileid using `categories(fileid)`.

# %%
for fileid in brown.fileids():
    print(fileid)
    print(brown.categories(fileid))
# Out:
# ca01
# ['news']
# ca02
# ['news']
# ca03
# ['news']
# ca04
# ['news']
# ca05
# ['news']
# ca06
# ['news']
# ca07
# ['news']
# ca08
# ['news']
# ca09
# ['news']
# ca10
# ['news']
# ca11
# ['news']
# ca12
# ['news']
# ca13
# ['news']
# ca14
# ['news']
# ca15
# ['news']
# ca16
# ['news']
# ca17
# ['news']
# ca18
# ['news']
# ca19
# ['news']
# ca20
# ['news']
# ca21
# ['news']
# ca22
# ['news']
# ca23
# ['news']
# ca24
# ['news']
# ca25
# ['news']
# ca26
# ['news']
# ca27
# ['news']
# ca28
# ['news']
# ca29
# ['news']
# ca30
# ['news']
# ca31
# ['news']
# ca32
# ['news']
# ca33
# ['news']
# ca34
# ['news']
# ca35
# ['news']
# ca36
# ['news']
# ca37
# ['news']
# ca38
# ['news']
# ca39
# ['news']
# ca40
# ['news']
# ca41
# ['news']
# ca42
# ['news']
# ca43
# ['news']
# ca44
# ['news']
# cb01
# ['editorial']
# cb02
# ['editorial']
# cb03
# ['editorial']
# cb04
# ['editorial']
# cb05
# ['editorial']
# cb06
# ['editorial']
# cb07
# ['editorial']
# cb08
# ['editorial']
# cb09
# ['editorial']
# cb10
# ['editorial']
# cb11
# ['editorial']
# cb12
# ['editorial']
# cb13
# ['editorial']
# cb14
# ['editorial']
# cb15
# ['editorial']
# cb16
# ['editorial']
# cb17
# ['editorial']
# cb18
# ['editorial']
# cb19
# ['editorial']
# cb20
# ['editorial']
# cb21
# ['editorial']
# cb22
# ['editorial']
# cb23
# ['editorial']
# cb24
# ['editorial']
# cb25
# ['editorial']
# cb26
# ['editorial']
# cb27
# ['editorial']
# cc01
# ['reviews']
# cc02
# ['reviews']
# cc03
# ['reviews']
# cc04
# ['reviews']
# cc05
# ['reviews']
# cc06
# ['reviews']
# cc07
# ['reviews']
# cc08
# ['reviews']
# cc09
# ['reviews']
# cc10
# ['reviews']
# cc11
# ['reviews']
# cc12
# ['reviews']
# cc13
# ['reviews']
# cc14
# ['reviews']
# cc15
# ['reviews']
# cc16
# ['reviews']
# cc17
# ['reviews']
# cd01
# ['religion']
# cd02
# ['religion']
# cd03
# ['religion']
# cd04
# ['religion']
# cd05
# ['religion']
# cd06
# ['religion']
# cd07
# ['religion']
# cd08
# ['religion']
# cd09
# ['religion']
# cd10
# ['religion']
# cd11
# ['religion']
# cd12
# ['religion']
# cd13
# ['religion']
# cd14
# ['religion']
# cd15
# ['religion']
# cd16
# ['religion']
# cd17
# ['religion']
# ce01
# ['hobbies']
# ce02
# ['hobbies']
# ce03
# ['hobbies']
# ce04
# ['hobbies']
# ce05
# ['hobbies']
# ce06
# ['hobbies']
# ce07
# ['hobbies']
# ce08
# ['hobbies']
# ce09
# ['hobbies']
# ce10
# ['hobbies']
# ce11
# ['hobbies']
# ce12
# ['hobbies']
# ce13
# ['hobbies']
# ce14
# ['hobbies']
# ce15
# ['hobbies']
# ce16
# ['hobbies']
# ce17
# ['hobbies']
# ce18
# ['hobbies']
# ce19
# ['hobbies']
# ce20
# ['hobbies']
# ce21
# ['hobbies']
# ce22
# ['hobbies']
# ce23
# ['hobbies']
# ce24
# ['hobbies']
# ce25
# ['hobbies']
# ce26
# ['hobbies']
# ce27
# ['hobbies']
# ce28
# ['hobbies']
# ce29
# ['hobbies']
# ce30
# ['hobbies']
# ce31
# ['hobbies']
# ce32
# ['hobbies']
# ce33
# ['hobbies']
# ce34
# ['hobbies']
# ce35
# ['hobbies']
# ce36
# ['hobbies']
# cf01
# ['lore']
# cf02
# ['lore']
# cf03
# ['lore']
# cf04
# ['lore']
# cf05
# ['lore']
# cf06
# ['lore']
# cf07
# ['lore']
# cf08
# ['lore']
# cf09
# ['lore']
# cf10
# ['lore']
# cf11
# ['lore']
# cf12
# ['lore']
# cf13
# ['lore']
# cf14
# ['lore']
# cf15
# ['lore']
# cf16
# ['lore']
# cf17
# ['lore']
# cf18
# ['lore']
# cf19
# ['lore']
# cf20
# ['lore']
# cf21
# ['lore']
# cf22
# ['lore']
# cf23
# ['lore']
# cf24
# ['lore']
# cf25
# ['lore']
# cf26
# ['lore']
# cf27
# ['lore']
# cf28
# ['lore']
# cf29
# ['lore']
# cf30
# ['lore']
# cf31
# ['lore']
# cf32
# ['lore']
# cf33
# ['lore']
# cf34
# ['lore']
# cf35
# ['lore']
# cf36
# ['lore']
# cf37
# ['lore']
# cf38
# ['lore']
# cf39
# ['lore']
# cf40
# ['lore']
# cf41
# ['lore']
# cf42
# ['lore']
# cf43
# ['lore']
# cf44
# ['lore']
# cf45
# ['lore']
# cf46
# ['lore']
# cf47
# ['lore']
# cf48
# ['lore']
# cg01
# ['belles_lettres']
# cg02
# ['belles_lettres']
# cg03
# ['belles_lettres']
# cg04
# ['belles_lettres']
# cg05
# ['belles_lettres']
# cg06
# ['belles_lettres']
# cg07
# ['belles_lettres']
# cg08
# ['belles_lettres']
# cg09
# ['belles_lettres']
# cg10
# ['belles_lettres']
# cg11
# ['belles_lettres']
# cg12
# ['belles_lettres']
# cg13
# ['belles_lettres']
# cg14
# ['belles_lettres']
# cg15
# ['belles_lettres']
# cg16
# ['belles_lettres']
# cg17
# ['belles_lettres']
# cg18
# ['belles_lettres']
# cg19
# ['belles_lettres']
# cg20
# ['belles_lettres']
# cg21
# ['belles_lettres']
# cg22
# ['belles_lettres']
# cg23
# ['belles_lettres']
# cg24
# ['belles_lettres']
# cg25
# ['belles_lettres']
# cg26
# ['belles_lettres']
# cg27
# ['belles_lettres']
# cg28
# ['belles_lettres']
# cg29
# ['belles_lettres']
# cg30
# ['belles_lettres']
# cg31
# ['belles_lettres']
# cg32
# ['belles_lettres']
# cg33
# ['belles_lettres']
# cg34
# ['belles_lettres']
# cg35
# ['belles_lettres']
# cg36
# ['belles_lettres']
# cg37
# ['belles_lettres']
# cg38
# ['belles_lettres']
# cg39
# ['belles_lettres']
# cg40
# ['belles_lettres']
# cg41
# ['belles_lettres']
# cg42
# ['belles_lettres']
# cg43
# ['belles_lettres']
# cg44
# ['belles_lettres']
# cg45
# ['belles_lettres']
# cg46
# ['belles_lettres']
# cg47
# ['belles_lettres']
# cg48
# ['belles_lettres']
# cg49
# ['belles_lettres']
# cg50
# ['belles_lettres']
# cg51
# ['belles_lettres']
# cg52
# ['belles_lettres']
# cg53
# ['belles_lettres']
# cg54
# ['belles_lettres']
# cg55
# ['belles_lettres']
# cg56
# ['belles_lettres']
# cg57
# ['belles_lettres']
# cg58
# ['belles_lettres']
# cg59
# ['belles_lettres']
# cg60
# ['belles_lettres']
# cg61
# ['belles_lettres']
# cg62
# ['belles_lettres']
# cg63
# ['belles_lettres']
# cg64
# ['belles_lettres']
# cg65
# ['belles_lettres']
# cg66
# ['belles_lettres']
# cg67
# ['belles_lettres']
# cg68
# ['belles_lettres']
# cg69
# ['belles_lettres']
# cg70
# ['belles_lettres']
# cg71
# ['belles_lettres']
# cg72
# ['belles_lettres']
# cg73
# ['belles_lettres']
# cg74
# ['belles_lettres']
# cg75
# ['belles_lettres']
# ch01
# ['government']
# ch02
# ['government']
# ch03
# ['government']
# ch04
# ['government']
# ch05
# ['government']
# ch06
# ['government']
# ch07
# ['government']
# ch08
# ['government']
# ch09
# ['government']
# ch10
# ['government']
# ch11
# ['government']
# ch12
# ['government']
# ch13
# ['government']
# ch14
# ['government']
# ch15
# ['government']
# ch16
# ['government']
# ch17
# ['government']
# ch18
# ['government']
# ch19
# ['government']
# ch20
# ['government']
# ch21
# ['government']
# ch22
# ['government']
# ch23
# ['government']
# ch24
# ['government']
# ch25
# ['government']
# ch26
# ['government']
# ch27
# ['government']
# ch28
# ['government']
# ch29
# ['government']
# ch30
# ['government']
# cj01
# ['learned']
# cj02
# ['learned']
# cj03
# ['learned']
# cj04
# ['learned']
# cj05
# ['learned']
# cj06
# ['learned']
# cj07
# ['learned']
# cj08
# ['learned']
# cj09
# ['learned']
# cj10
# ['learned']
# cj11
# ['learned']
# cj12
# ['learned']
# cj13
# ['learned']
# cj14
# ['learned']
# cj15
# ['learned']
# cj16
# ['learned']
# cj17
# ['learned']
# cj18
# ['learned']
# cj19
# ['learned']
# cj20
# ['learned']
# cj21
# ['learned']
# cj22
# ['learned']
# cj23
# ['learned']
# cj24
# ['learned']
# cj25
# ['learned']
# cj26
# ['learned']
# cj27
# ['learned']
# cj28
# ['learned']
# cj29
# ['learned']
# cj30
# ['learned']
# cj31
# ['learned']
# cj32
# ['learned']
# cj33
# ['learned']
# cj34
# ['learned']
# cj35
# ['learned']
# cj36
# ['learned']
# cj37
# ['learned']
# cj38
# ['learned']
# cj39
# ['learned']
# cj40
# ['learned']
# cj41
# ['learned']
# cj42
# ['learned']
# cj43
# ['learned']
# cj44
# ['learned']
# cj45
# ['learned']
# cj46
# ['learned']
# cj47
# ['learned']
# cj48
# ['learned']
# cj49
# ['learned']
# cj50
# ['learned']
# cj51
# ['learned']
# cj52
# ['learned']
# cj53
# ['learned']
# cj54
# ['learned']
# cj55
# ['learned']
# cj56
# ['learned']
# cj57
# ['learned']
# cj58
# ['learned']
# cj59
# ['learned']
# cj60
# ['learned']
# cj61
# ['learned']
# cj62
# ['learned']
# cj63
# ['learned']
# cj64
# ['learned']
# cj65
# ['learned']
# cj66
# ['learned']
# cj67
# ['learned']
# cj68
# ['learned']
# cj69
# ['learned']
# cj70
# ['learned']
# cj71
# ['learned']
# cj72
# ['learned']
# cj73
# ['learned']
# cj74
# ['learned']
# cj75
# ['learned']
# cj76
# ['learned']
# cj77
# ['learned']
# cj78
# ['learned']
# cj79
# ['learned']
# cj80
# ['learned']
# ck01
# ['fiction']
# ck02
# ['fiction']
# ck03
# ['fiction']
# ck04
# ['fiction']
# ck05
# ['fiction']
# ck06
# ['fiction']
# ck07
# ['fiction']
# ck08
# ['fiction']
# ck09
# ['fiction']
# ck10
# ['fiction']
# ck11
# ['fiction']
# ck12
# ['fiction']
# ck13
# ['fiction']
# ck14
# ['fiction']
# ck15
# ['fiction']
# ck16
# ['fiction']
# ck17
# ['fiction']
# ck18
# ['fiction']
# ck19
# ['fiction']
# ck20
# ['fiction']
# ck21
# ['fiction']
# ck22
# ['fiction']
# ck23
# ['fiction']
# ck24
# ['fiction']
# ck25
# ['fiction']
# ck26
# ['fiction']
# ck27
# ['fiction']
# ck28
# ['fiction']
# ck29
# ['fiction']
# cl01
# ['mystery']
# cl02
# ['mystery']
# cl03
# ['mystery']
# cl04
# ['mystery']
# cl05
# ['mystery']
# cl06
# ['mystery']
# cl07
# ['mystery']
# cl08
# ['mystery']
# cl09
# ['mystery']
# cl10
# ['mystery']
# cl11
# ['mystery']
# cl12
# ['mystery']
# cl13
# ['mystery']
# cl14
# ['mystery']
# cl15
# ['mystery']
# cl16
# ['mystery']
# cl17
# ['mystery']
# cl18
# ['mystery']
# cl19
# ['mystery']
# cl20
# ['mystery']
# cl21
# ['mystery']
# cl22
# ['mystery']
# cl23
# ['mystery']
# cl24
# ['mystery']
# cm01
# ['science_fiction']
# cm02
# ['science_fiction']
# cm03
# ['science_fiction']
# cm04
# ['science_fiction']
# cm05
# ['science_fiction']
# cm06
# ['science_fiction']
# cn01
# ['adventure']
# cn02
# ['adventure']
# cn03
# ['adventure']
# cn04
# ['adventure']
# cn05
# ['adventure']
# cn06
# ['adventure']
# cn07
# ['adventure']
# cn08
# ['adventure']
# cn09
# ['adventure']
# cn10
# ['adventure']
# cn11
# ['adventure']
# cn12
# ['adventure']
# cn13
# ['adventure']
# cn14
# ['adventure']
# cn15
# ['adventure']
# cn16
# ['adventure']
# cn17
# ['adventure']
# cn18
# ['adventure']
# cn19
# ['adventure']
# cn20
# ['adventure']
# cn21
# ['adventure']
# cn22
# ['adventure']
# cn23
# ['adventure']
# cn24
# ['adventure']
# cn25
# ['adventure']
# cn26
# ['adventure']
# cn27
# ['adventure']
# cn28
# ['adventure']
# cn29
# ['adventure']
# cp01
# ['romance']
# cp02
# ['romance']
# cp03
# ['romance']
# cp04
# ['romance']
# cp05
# ['romance']
# cp06
# ['romance']
# cp07
# ['romance']
# cp08
# ['romance']
# cp09
# ['romance']
# cp10
# ['romance']
# cp11
# ['romance']
# cp12
# ['romance']
# cp13
# ['romance']
# cp14
# ['romance']
# cp15
# ['romance']
# cp16
# ['romance']
# cp17
# ['romance']
# cp18
# ['romance']
# cp19
# ['romance']
# cp20
# ['romance']
# cp21
# ['romance']
# cp22
# ['romance']
# cp23
# ['romance']
# cp24
# ['romance']
# cp25
# ['romance']
# cp26
# ['romance']
# cp27
# ['romance']
# cp28
# ['romance']
# cp29
# ['romance']
# cr01
# ['humor']
# cr02
# ['humor']
# cr03
# ['humor']
# cr04
# ['humor']
# cr05
# ['humor']
# cr06
# ['humor']
# cr07
# ['humor']
# cr08
# ['humor']
# cr09
# ['humor']

# %% [markdown]
# Another extremely common annotation is a part-of-speech (POS) tag. In NLTK, POS tags are accessed using by using `tagged_words()` and `tagged_sents()`. The difference between these methods and their non-tagged equivalent is the string corresponding to a word token is replaced with a (token,POS) *tuple*.

# %%
brown.tagged_words()[0]
# Out:
# ('The', 'AT')

# %%
first_tagged_sent = brown.tagged_sents()[0]
first_tagged_sent
# Out:
# [('The', 'AT'),
#  ('Fulton', 'NP-TL'),
#  ('County', 'NN-TL'),
#  ('Grand', 'JJ-TL'),
#  ('Jury', 'NN-TL'),
#  ('said', 'VBD'),
#  ('Friday', 'NR'),
#  ('an', 'AT'),
#  ('investigation', 'NN'),
#  ('of', 'IN'),
#  ("Atlanta's", 'NP$'),
#  ('recent', 'JJ'),
#  ('primary', 'NN'),
#  ('election', 'NN'),
#  ('produced', 'VBD'),
#  ('``', '``'),
#  ('no', 'AT'),
#  ('evidence', 'NN'),
#  ("''", "''"),
#  ('that', 'CS'),
#  ('any', 'DTI'),
#  ('irregularities', 'NNS'),
#  ('took', 'VBD'),
#  ('place', 'NN'),
#  ('.', '.')]

# %% [markdown]
# When iterating over tuples, don't forget you can extract the elements in the header of the `for` loop!

# %%
for word, pos in first_tagged_sent:
    print(pos)
# Out:
# AT
# NP-TL
# NN-TL
# JJ-TL
# NN-TL
# VBD
# NR
# AT
# NN
# IN
# NP$
# JJ
# NN
# NN
# VBD
# ``
# AT
# NN
# ''
# CS
# DTI
# NNS
# VBD
# NN
# .

# %% [markdown]
# It is worth noting that there are various different POS tag sets, even for just English. In recent years there has been a push towards a universal set that works for all languages. We can get the universal tagset by using the `tagset='universal'` keyword argument.

# %%
brown.tagged_sents(tagset='universal')[0]
# Out:
# [('The', 'DET'),
#  ('Fulton', 'NOUN'),
#  ('County', 'NOUN'),
#  ('Grand', 'ADJ'),
#  ('Jury', 'NOUN'),
#  ('said', 'VERB'),
#  ('Friday', 'NOUN'),
#  ('an', 'DET'),
#  ('investigation', 'NOUN'),
#  ('of', 'ADP'),
#  ("Atlanta's", 'NOUN'),
#  ('recent', 'ADJ'),
#  ('primary', 'NOUN'),
#  ('election', 'NOUN'),
#  ('produced', 'VERB'),
#  ('``', '.'),
#  ('no', 'DET'),
#  ('evidence', 'NOUN'),
#  ("''", '.'),
#  ('that', 'ADP'),
#  ('any', 'DET'),
#  ('irregularities', 'NOUN'),
#  ('took', 'VERB'),
#  ('place', 'NOUN'),
#  ('.', '.')]

# %% [markdown]
# For this course, make sure you know what each tag in the [universal tag set](https://universaldependencies.org/u/pos/) means and can give examples: these are _fundamental_ linguistic concepts that anyone who works with language should know!

# %% [markdown]
# ## Other corpora and annotations
#
# NLTK is just a small, easy to access sample of full range of corpora out there. Here are some others, ranging for well-known and very useful to more obscure but cool!
#
# * The entirety of Wikipedia is [downloadable](https://en.wikipedia.org/wiki/Wikipedia:Database_download). It is popular as a raw source of language data for various languages and also has interesting annotations, for instance the page structure and the edit history!
# * The [Gigaword corpus](https://catalog.ldc.upenn.edu/LDC2012T21) is a huge newspaper corpus with lots of useful annotation, though it requires an LDC subscription
# * [The British National Corpus](http://www.natcorp.ox.ac.uk/) and [American National Corpus](http://www.anc.org/) are (like the Brown) balanced corpora reflecting a diversity of language genres and modalities in their respective countries, but at a much larger scale than the Brown.
# * There are lots of big corpora of online reviews, e.g. [Amazon reviews](https://snap.stanford.edu/data/web-Amazon.html)
# * Questions and answers from [Yahoo answers](https://webscope.sandbox.yahoo.com/catalog.php?datatype=l&guccounter=1)
# * Large corpus of [Reddit comments](https://www.kaggle.com/reddit/reddit-comments-may-2015)
# * Corpus of [blogger.com blogs](http://u.cs.biu.ac.il/~koppel/BlogCorpus.htm) with user ids and background (gender/age)
# * The [Cambridge Learner Corpus](https://ilexir.co.uk/datasets/index.html) written by non-native learners of English, with error annotations
# * The [Enron e-mail corpus](https://aws.amazon.com/de/datasets/enron-email-data/), over a million internal e-mails of a now defunct company, used for studies of power relationships
# * The [Hansards](https://www.isi.edu/natural-language/download/hansard/), proceedings of Canadian parliment, English-French parallel text used for machine translation
# * The [Cornell Movie Dialogue Corpus](http://www.cs.cornell.edu/~cristian/Cornell_Movie-Dialogs_Corpus.html), scripts from 617 movies with character annotations
# * [Jeopardy](https://www.reddit.com/r/datasets/comments/1uyd0t/200000_jeopardy_questions_in_a_json_file/) questions and answers
# * ...
